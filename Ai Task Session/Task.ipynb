# %%
#add two numbers
a=1.7
b=20.7
sum=a+b
print('the sum of {0} and {1} is {2}'.format(a,b,sum))
# Out:
# the sum of 1.7 and 20.7 is 22.4

# %%
#store input
f=input('Enter 1st number: ')
k=input('Enter 1st number: ')
sum=float(f)+float(k)
print('the sum of {0} and {1} is {2}'.format(f,k,sum))
# Out:
# Enter 1st number:  207
# Enter 1st number:  230
# the sum of 207 and 230 is 437.0

# %%
#calculate square root
num=7
num_sqrt=num**0.5
print('the square root of%0.3f is%0.3f'%(num,num_sqrt))
# Out:
# the square root of7.000 is2.646
