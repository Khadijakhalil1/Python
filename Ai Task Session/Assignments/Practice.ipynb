# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('salary_data.csv')

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
# Transform tab use hota hai jab hum data ko change/scale/encode karte hain.(Transform is not the attribute of linear regression ,so we can't do the transform in linear regression)
# Examples:
# StandardScaler
# MinMaxScaler
# OneHotEncoder
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     YearsExperience
# 1               1.3
# 0               1.1
# 14              4.5
# 9               3.7
# 21              7.1
# 19              6.0

# %%
y_test
# Out:
# 1     46205
# 0     39343
# 14    61111
# 9     57189
# 21    98273
# 19    93940
# Name: Salary, dtype: int64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36833.63210301])

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
# impact of each feature on prediction
# How much each input feature affects the output.
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([106500.22462896])

# %%
m * 9.5 + b
# Out:
# array([115304.24456356])

# %%
m * 100 + b
# Out:
# array([981351.85769523])
