# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv('text_preprocessing_1000_rows.csv')

# %%
df.sample(5)
# Out:
#       id                                               text
# 855  856          Repeated letters: cooool loooove tweeeeet
# 148  149   Python, Java, and C++ are programming languages.
# 354  355  Remove punctuation, lowercase, and stopwords f...
# 497  498    <p>Hello there! Visit https://example.com 😊</p>
# 850  851  Python is awesome!!! Check out www.python.org ...

# %%
df.isnull().sum()
# Out:
# id      0
# text    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['text'].head(10)
# Out:
# 0                 Mixed CASE text should be lowercased
# 1      Newlines\nand\ttabs should be handled properly.
# 2    <div>HTML tags everywhere! <b>Bold</b> and <i>...
# 3    I love NLP. It’s amazing… <a href='link'>Click...
# 4     Numbers 12345 and 67890 are present in this text
# 5    Check out this link: https://github.com/user/repo
# 6    Remove punctuation, lowercase, and stopwords f...
# 7      I am loving #MachineLearning and #DataScience 🌟
# 8    Stemming and lemmatization are key for text no...
# 9    Python is awesome!!! Check out www.python.org ...
# Name: text, dtype: object

# %% [markdown]
# ## Removing HTML tags

# %%
import re
def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)
df['text'] = df['text'].apply(remove_html_tags)

# %%
df['text'].head(10)
# Out:
# 0                 Mixed CASE text should be lowercased
# 1      Newlines\nand\ttabs should be handled properly.
# 2                HTML tags everywhere! Bold and Italic
# 3                 I love NLP. It’s amazing… Click here
# 4     Numbers 12345 and 67890 are present in this text
# 5    Check out this link: https://github.com/user/repo
# 6    Remove punctuation, lowercase, and stopwords f...
# 7      I am loving #MachineLearning and #DataScience 🌟
# 8    Stemming and lemmatization are key for text no...
# 9    Python is awesome!!! Check out www.python.org ...
# Name: text, dtype: object

# %% [markdown]
# ## Removing URLS

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)
df['text'] = df['text'].apply(remove_urls)

# %%
df['text'].head(10)
# Out:
# 0                 Mixed CASE text should be lowercased
# 1      Newlines\nand\ttabs should be handled properly.
# 2                HTML tags everywhere! Bold and Italic
# 3                 I love NLP. It’s amazing… Click here
# 4     Numbers 12345 and 67890 are present in this text
# 5                                Check out this link:
# 6    Remove punctuation, lowercase, and stopwords f...
# 7      I am loving #MachineLearning and #DataScience 🌟
# 8    Stemming and lemmatization are key for text no...
# 9            Python is awesome!!! Check out  😎 #coding
# Name: text, dtype: object

# %% [markdown]
# ## Removing Punctuations

# %%
import string
def remove_punc(text):
    return text.translate(str.maketrans('', '', string.punctuation))
df['text'] = df['text'].apply(remove_punc)

# %%
df['text'].head(10)
# Out:
# 0                 Mixed CASE text should be lowercased
# 1       Newlines\nand\ttabs should be handled properly
# 2                 HTML tags everywhere Bold and Italic
# 3                  I love NLP It’s amazing… Click here
# 4     Numbers 12345 and 67890 are present in this text
# 5                                 Check out this link
# 6    Remove punctuation lowercase and stopwords fro...
# 7        I am loving MachineLearning and DataScience 🌟
# 8    Stemming and lemmatization are key for text no...
# 9                Python is awesome Check out  😎 coding
# Name: text, dtype: object

# %% [markdown]
# ## LowerCasing

# %%
df['text'] = df['text'].str.lower()

# %%
df['text'].head(10)
# Out:
# 0                 mixed case text should be lowercased
# 1       newlines\nand\ttabs should be handled properly
# 2                 html tags everywhere bold and italic
# 3                  i love nlp it’s amazing… click here
# 4     numbers 12345 and 67890 are present in this text
# 5                                 check out this link
# 6    remove punctuation lowercase and stopwords fro...
# 7        i am loving machinelearning and datascience 🌟
# 8    stemming and lemmatization are key for text no...
# 9                python is awesome check out  😎 coding
# Name: text, dtype: object

# %% [markdown]
# ## Chat word treatment

# %%
chat_word = {
    "U": "you",
    "R": "are",
    "UR": "your",
    "BRB": "be right back",
    "LOL": "laughing out loud",
    "OMG": "oh my god",
    "IDK": "I don’t know",
    "TBH": "to be honest",
    "BTW": "by the way",
    "GTG": "got to go",
    "BFF": "best friends forever",
    "ROFL": "rolling on the floor laughing",
    "TTYL": "talk to you later",
    "IMO": "in my opinion",
    "IMHO": "in my humble opinion",
    "FYI": "for your information",
    "LMAO": "laughing my ass off",
    "NP": "no problem",
    "THX": "thanks",
    "TY": "thank you",
    "PLZ": "please",
    "CUL8R": "see you later",
    "GR8": "great",
    "NVM": "never mind",
    "SMH": "shaking my head",
    "IDC": "I don’t care",
    "ILY": "I love you",
    "YOLO": "you only live once",
    "TMI": "too much information",
    "AFK": "away from keyboard",
    "OMW": "on my way",
    "FAQ": "frequently asked questions",
    "ASAP": "as soon as possible",
    "FOMO": "fear of missing out"}
def chat_word_conversion(text):
    new_text = []
    for w in text.split(): # it will split the words in a sentence by spaces into a list.
        if w.upper() in chat_word: #Check if the word is in dictionary
            new_text.append(chat_word[w.upper()]) #This finds the full form of the chat word and appends it.
        else:
            new_text.append(w)
    return " ".join(new_text) #joins all words with spaces back into a sentence.

# %%
df['text'] = df['text'].apply(chat_word_conversion)

# %%
df['text'].head(10)
# Out:
# 0                 mixed case text should be lowercased
# 1         newlines and tabs should be handled properly
# 2                 html tags everywhere bold and italic
# 3                  i love nlp it’s amazing… click here
# 4     numbers 12345 and 67890 are present in this text
# 5                                  check out this link
# 6    remove punctuation lowercase and stopwords fro...
# 7        i am loving machinelearning and datascience 🌟
# 8    stemming and lemmatization are key for text no...
# 9                 python is awesome check out 😎 coding
# Name: text, dtype: object

# %% [markdown]
# ## Spelling Correction

# %%
from textblob import TextBlob
def Spell_Correct(incorrect_text):
   
    textBlb = TextBlob(str(incorrect_text)) #creating TextBlob object
    text= str(textBlb.correct())
    return text

# %%
df['text'] = df['text'].apply(Spell_Correct)

# %%
df['text'].head(10)
# Out:
# 0                 mixed case text should be lowercased
# 1        newlands and tabes should be handled properly
# 2                html tags everywhere bold and italian
# 3                  i love nap it’s amazing… click here
# 4     numbers 12345 and 67890 are present in this text
# 5                                  check out this link
# 6    remove punctuation lowercase and stopford from...
# 7        i am loving machinelearning and datascience 🌟
# 8    steaming and lemmatization are key for text no...
# 9                 patron is awesome check out 😎 coming
# Name: text, dtype: object

# %% [markdown]
# ## Removing emojis

# %%
import emoji
def emoji_removal(text):
    text = emoji.demojize(text)
    return text

# %%
df['text'] = df['text'].apply(emoji_removal) # ye emoji k meaning se replace kre ga

# %%
df['text'].head(10)
# Out:
# 0                 mixed case text should be lowercased
# 1        newlands and tabes should be handled properly
# 2                html tags everywhere bold and italian
# 3                  i love nap it’s amazing… click here
# 4     numbers 12345 and 67890 are present in this text
# 5                                  check out this link
# 6    remove punctuation lowercase and stopford from...
# 7    i am loving machinelearning and datascience :g...
# 8    steaming and lemmatization are key for text no...
# 9    patron is awesome check out :smiling_face_with...
# Name: text, dtype: object

# %% [markdown]
# ## Tokenization

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

def token(text):
    doc = nlp(text)
    return [token.text for token in doc]

# %%
df['text'] = df['text'].apply(token)

# %%
df['text'].head(10)
# Out:
# 0          [mixed, case, text, should, be, lowercased]
# 1    [newlands, and, tabes, should, be, handled, pr...
# 2         [html, tags, everywhere, bold, and, italian]
# 3      [i, love, nap, it, ’s, amazing, …, click, here]
# 4    [numbers, 12345, and, 67890, are, present, in,...
# 5                             [check, out, this, link]
# 6    [remove, punctuation, lowercase, and, stopford...
# 7    [i, am, loving, machinelearning, and, datascie...
# 8    [steaming, and, lemmatization, are, key, for, ...
# 9    [patron, is, awesome, check, out, :, smiling_f...
# Name: text, dtype: object

# %% [markdown]
# ## Stemming

# %%
from nltk import PorterStemmer
ps = PorterStemmer()
def stemming(text):
    return [ps.stem(word) for word in text]

# %%
df['text'] = df['text'].apply(stemming)

# %%
df['text'].head(10)
# Out:
# 0              [mix, case, text, should, be, lowercas]
# 1    [newland, and, tabe, should, be, handl, properli]
# 2           [html, tag, everywher, bold, and, italian]
# 3         [i, love, nap, it, ’s, amaz, …, click, here]
# 4    [number, 12345, and, 67890, are, present, in, ...
# 5                              [check, out, thi, link]
# 6    [remov, punctuat, lowercas, and, stopford, fro...
# 7    [i, am, love, machinelearn, and, datasci, :, g...
# 8    [steam, and, lemmat, are, key, for, text, norm...
# 9    [patron, is, awesom, check, out, :, smiling_fa...
# Name: text, dtype: object

# %% [markdown]
# ## Lemitization

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
def token_lemmatized(text):
    # Convert everything to string first
    text = str(text)
    doc = nlp(text)
    

   
    print(doc[0].lemma_)

# %%
df['text'] = df['text'].apply(token_lemmatized)
# Out:
# mixed
# newline
# html
# I
# number
# check
# remove
# I
# stem
# python
# emoji
# mixed
# mention
# stem
# number
# data
# python
# python
# email
# stem
# number
# remove
# data
# I
# mixed
# html
# stem
# mention
# html
# mixed
# I
# mixed
# repeat
# python
# html
# special
# python
# stem
# newline
# hello
# check
# mixed
# special
# remove
# data
# hello
# misspellings
# repeat
# hello
# emoji
# remove
# data
# I
# email
# I
# email
# email
# misspellings
# emoji
# emoji
# clean
# python
# clean
# email
# emoji
# clean
# remove
# I
# newline
# repeat
# check
# stem
# html
# I
# clean
# clean
# clean
# email
# mention
# newline
# I
# misspellings
# I
# html
# python
# misspellings
# html
# html
# newline
# I
# repeat
# hello
# misspellings
# html
# I
# newline
# repeat
# emoji
# email
# check
# I
# html
# emoji
# I
# remove
# mention
# html
# hello
# repeat
# email
# python
# I
# I
# mixed
# special
# special
# I
# email
# html
# email
# email
# number
# emoji
# clean
# hello
# remove
# remove
# I
# stem
# emoji
# email
# python
# repeat
# repeat
# repeat
# python
# hello
# hello
# repeat
# number
# html
# I
# check
# newline
# repeat
# python
# I
# mixed
# python
# hello
# remove
# hello
# mixed
# stem
# python
# email
# python
# mixed
# stem
# mention
# special
# python
# emoji
# misspellings
# misspellings
# hello
# check
# I
# number
# clean
# stem
# hello
# check
# html
# hello
# stem
# clean
# misspellings
# clean
# I
# data
# newline
# I
# special
# email
# python
# I
# html
# repeat
# mention
# number
# misspellings
# email
# I
# mention
# email
# emoji
# repeat
# data
# mention
# python
# number
# I
# remove
# number
# clean
# clean
# clean
# python
# stem
# repeat
# hello
# remove
# check
# mention
# remove
# python
# email
# clean
# misspellings
# data
# I
# remove
# email
# stem
# mixed
# I
# misspellings
# html
# check
# newline
# misspellings
# number
# mention
# mixed
# repeat
# I
# emoji
# stem
# check
# check
# repeat
# python
# number
# stem
# special
# stem
# number
# number
# mixed
# data
# email
# clean
# remove
# clean
# hello
# python
# newline
# misspellings
# I
# html
# misspellings
# emoji
# clean
# clean
# I
# mention
# misspellings
# check
# clean
# mention
# newline
# remove
# number
# mention
# mixed
# special
# remove
# mixed
# check
# data
# emoji
# remove
# data
# hello
# stem
# mention
# python
# data
# number
# python
# python
# misspellings
# email
# number
# mention
# hello
# stem
# misspellings
# mixed
# special
# check
# html
# mention
# python
# repeat
# email
# hello
# data
# mention
# number
# clean
# emoji
# python
# I
# clean
# number
# misspellings
# special
# number
# mention
# email
# special
# check
# email
# newline
# special
# special
# check
# mixed
# I
# python
# check
# hello
# email
# I
# python
# I
# misspellings
# remove
# emoji
# newline
# newline
# python
# remove
# html
# repeat
# special
# repeat
# data
# special
# repeat
# python
# check
# remove
# misspellings
# remove
# number
# clean
# mention
# repeat
# misspellings
# number
# special
# mention
# newline
# html
# misspellings
# mixed
# remove
# misspellings
# repeat
# emoji
# python
# I
# emoji
# hello
# check
# emoji
# misspellings
# repeat
# I
# I
# html
# check
# python
# emoji
# clean
# email
# misspellings
# html
# clean
# special
# clean
# hello
# check
# html
# data
# newline
# mixed
# number
# remove
# clean
# stem
# python
# I
# mention
# I
# html
# email
# python
# mixed
# newline
# mixed
# python
# emoji
# I
# stem
# python
# data
# newline
# remove
# number
# clean
# special
# remove
# remove
# I
# emoji
# email
# number
# python
# email
# python
# html
# python
# data
# remove
# number
# newline
# newline
# remove
# newline
# python
# python
# special
# data
# hello
# python
# python
# special
# remove
# misspellings
# python
# newline
# emoji
# mention
# email
# mention
# python
# number
# stem
# misspellings
# mixed
# newline
# email
# python
# clean
# python
# mention
# number
# mixed
# I
# clean
# python
# special
# mixed
# check
# number
# hello
# I
# number
# repeat
# data
# special
# special
# I
# special
# check
# remove
# I
# newline
# mention
# I
# mention
# remove
# mixed
# hello
# remove
# data
# I
# emoji
# misspellings
# emoji
# repeat
# mixed
# I
# email
# newline
# I
# stem
# number
# emoji
# mixed
# clean
# remove
# email
# html
# data
# newline
# number
# clean
# mixed
# html
# I
# misspellings
# number
# special
# hello
# remove
# email
# repeat
# remove
# remove
# python
# hello
# data
# html
# data
# special
# email
# data
# repeat
# python
# number
# clean
# stem
# check
# emoji
# emoji
# repeat
# I
# mention
# stem
# repeat
# data
# emoji
# hello
# mixed
# mixed
# clean
# html
# number
# number
# remove
# remove
# check
# python
# email
# python
# I
# python
# special
# check
# email
# python
# repeat
# stem
# remove
# I
# stem
# data
