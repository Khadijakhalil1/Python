# %%
# Mean(Manual Method)
population = [15,14,13,12,17,16]
sample = [1,9,2,4]

pop_mean = sum(population)/len(population)
print(pop_mean)

sample_mean = sum(sample)/len(sample)
print(sample_mean)
# Out:
# 14.5
# 4.0

# %%
a=207
b=232
print(a+b)
# Out:
# 439

# %%
print("hello")
# Out:
# hello

# %%
population=[1,2,4,5]
sample=[77,5,8,2]
pop_mean=sum(population)/len(population)
print(pop_mean)

sample_mean=sum(sample)/len(sample)
print(sample_mean)
# Out:
# 3.0
# 23.0

# %%
# Mean(Using Numpy)
import numpy as np
a= [2,3,4,6]
b=np.mean(a)
print(b)
# Out:
# 3.75

# %%
# Mean(Using Satastic)
import statistics as stat
# Mode(using stat)
var =[4,77,12,8,44,12,44]
var_mean=stat.mean(var)
print("Mean",var_mean)

var_mode=stat.multimode(var)
var_mode2=stat.mode(var)
print("MultiMode",var_mode)
print("Mode",var_mode2)
# Out:
# Mean 28.714285714285715
# MultiMode [12, 44]
# Mode 12

# %%
# Mode(using scipy)
from scipy import stats
d =[3,5,77,22,3]
mode =stats.mode(d)
print("Mode using scipy: ",mode)
# Out:
# Mode using scipy:  ModeResult(mode=np.int64(3), count=np.int64(2))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create a Figure and axes
fig , axs = plt.subplots(3,2,figsize=(14,12))
fig.suptitle("Histogram with KDE of Various Distributions", fontsize=16)

# Normal Distribution 

data_normal = np.random.normal(loc=0,scale=1,size=1000) # Mean=0, std=1
sns.histplot(data_normal,kde=True,ax=axs[0,0],color="blue",stat="density",bins=30)
axs[0,0].set_title("Normal Distribution")
axs[0,0].grid(True)

data_right_skewed = np.random.exponential(scale=1,size=1000)
data_left_skewed = -np.random.exponential(scale=1,size=1000)

# Right Skewed Histogram
sns.histplot(data_right_skewed,kde=True,ax=axs[0,1],color="pink",stat="density",bins=30,label="Right Skewed")


# left Skewed Histogram
sns.histplot(data_left_skewed,kde=True,ax=axs[0,1],color="yellow",stat="density",bins=30,label="Left Skewed")
axs[0,1].set_title("Skewed Distribution")
axs[0,1].legend()
axs[0,1].grid(True)

# Uniform Distribution
data_uniform = np.random.uniform(low=0,high=1,size=1000)
sns.histplot(data_uniform,kde=True,ax=axs[1,0],color="purple",stat="density",bins=30)
axs[1,0].set_title("Uniform Distribution")
axs[1,0].grid(True)


# Bimodal Distribution
data_bimodal = np.concatenate([np.random.normal(loc=-2,scale=1,size=500),
                               np.random.normal(loc=2,scale=1,size=500)])
sns.histplot(data_bimodal,kde=True,ax=axs[1,1],color="red",stat="density",bins=30)
axs[1,1].set_title("Bimodal Distribution")
axs[1,1].grid(True)

# Multimodal Distribution
data_Multimodal = np.concatenate([np.random.normal(loc=-6,scale=1.5,size=500),
                               np.random.normal(loc=0,scale=1,size=500),
                               np.random.normal(loc=6,scale=1.5,size=500)])
sns.histplot(data_Multimodal,kde=True,ax=axs[2,0],color="black",stat="density",bins=30)
axs[2,0].set_title("Multimodal Distribution")
axs[2,0].grid(True)

# Hide Empty subplot
axs[2,1].axis("off")
# adjust layout
plt.tight_layout(rect=[0,0,1,0.96])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create a Figure and axes
fig , axs = plt.subplots(3,2,figsize=(14,12))
fig.suptitle("Histogram with KDE of Various Distributions", fontsize=16)

# Normal Distribution 

data_normal = np.random.normal(loc=0,scale=1,size=1000) # Mean=0, std=1
sns.histplot(data_normal,kde=True,ax=axs[0,0],color="blue",stat="density",bins=30)
axs[0,0].set_title("Normal Distribution")
axs[0,0].grid(True)

data_right_skewed = np.random.exponential(scale=1,size=1000)
data_left_skewed = -np.random.exponential(scale=1,size=1000)

# Right Skewed Histogram
sns.histplot(data_right_skewed,kde=True,ax=axs[0,1],color="pink",stat="density",bins=30,label="Right Skewed")


# left Skewed Histogram
sns.histplot(data_left_skewed,kde=True,ax=axs[0,1],color="yellow",stat="density",bins=30,label="Left Skewed")
axs[0,1].set_title("Skewed Distribution")
axs[0,1].legend()
axs[0,1].grid(True)

# Uniform Distribution
data_uniform = np.random.uniform(low=0,high=1,size=1000)
sns.histplot(data_uniform,kde=True,ax=axs[1,0],color="purple",stat="density",bins=30)
axs[1,0].set_title("Uniform Distribution")
axs[1,0].grid(True)


# Bimodal Distribution
data_bimodal = np.concatenate([np.random.normal(loc=-2,scale=1,size=500),
                               np.random.normal(loc=2,scale=1,size=500)])
sns.histplot(data_bimodal,kde=True,ax=axs[1,1],color="red",stat="density",bins=30)
axs[1,1].set_title("Bimodal Distribution")
axs[1,1].grid(True)

# Multimodal Distribution
data_Multimodal = np.concatenate([np.random.normal(loc=-6,scale=1.5,size=500),
                               np.random.normal(loc=0,scale=1,size=500),
                               np.random.normal(loc=6,scale=1.5,size=500)])
sns.histplot(data_Multimodal,kde=True,ax=axs[2,0],color="black",stat="density",bins=30)
axs[2,0].set_title("Multimodal Distribution")
axs[2,0].grid(True)

# Hide Empty subplot
axs[2,1].axis("off")
# adjust layout
plt.tight_layout(rect=[0,0,1,0.96])
plt.show()

# %%
print("hello")
# Out:
# hello
