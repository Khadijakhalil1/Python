# %%
def say_here():
    print("Hello khadija")
say_here()
# Out:
# Hello khadija

# %%
F =input("Enter your Favourite Fruit")
def greet(F):
    print("Here is your frt Fruit",F) 

    
greet(F)
# Out:
# Enter your Favourite Fruit Apple
# Here is your frt Fruit Apple

# %%
def khadi(k,f):
    print(k+f)
khadi(207,230)
# Out:
# 437

# %%
def square(n):
    return n*n
print(square(6))
# Out:
# 36

# %%
def f(k):
    return k[::-3]
print(f("khadija"))
# Out:
# adk

# %%
lst = list(map(int, input("Enter Numbers Separated  by space:")))

def list_sum(lst):
    return sum(lst)
    
print(list_sum(lst))
# Out:
# Enter Numbers Separated  by space: 111
# 3
